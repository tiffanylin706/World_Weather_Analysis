# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 650

# %%
# Import the requests library.
import requests

# Import the API key.
from config import OpenWeather_API_KEY

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1a02fcc11dd9529e28e216d130db2495

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | deputatskiy
# Processing Record 3 of Set 1 | quatre cocos
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | coahuayana
# Processing Record 13 of Set 1 | lusambo
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | gua musang
# Processing Record 16 of Set 1 | flin flon
# Processing Record 17 of Set 1 | anadyr
# Processing Record 18 of Set 1 | douglas
# Processing Record 19 of Set 1 | gimli
# Processing Record 20 of Set 1 | vila velha
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | bjorkelangen
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | mahanoro
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | vikhorevka
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | cockburn town
# Processing Record 40 of Set 1 | hassleholm
# Processing Record 41 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 1 | maykain
# City not found. Skipping...
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 1 | cape canaveral
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | mecca
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | katobu
# Processing Record 4 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 2 | husavik
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | eureka
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | odweyne
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | kahului
# Processing Record 18 of Set 2 | kochubey
# Processing Record 19 of Set 2 | kaeo
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | nemuro
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | vao
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | hastings
# Processing Record 27 of Set 2 | mantua
# Processing Record 28 of Set 2 | grand-bourg
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | swan river
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | alamogordo
# Processing Record 33 of Set 2 | leua
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | beloha
# Processing Record 37 of Set 2 | churapcha
# Processing Record 38 of Set 2 | vilkaviskis
# Processing Record 39 of Set 2 | prince rupert
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | henties bay
# Processing Record 42 of Set 2 | noumea
# Processing Record 43 of Set 2 | solnechnyy
# Processing Record 44 of Set 2 | sao filipe
# Processing Record 45 of Set 2 | iqaluit
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | muros
# Processing Record 1 of Set 3 | ulladulla
# Processing Record 2 of Set 3 | lima
# Processing Record 3 of Set 3 | huarmey
# Processing Record 4 of Set 3 | pacific grove
# Processing Record 5 of Set 3 | bagnolo mella
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | mogadishu
# Processing Record 8 of Set 3 | pueblo nuevo
# Processing Record 9 of Set 3 | yarkovo
# Processing Record 10 of Set 3 | sidi ali
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | amahai
# Processing Record 13 of Set 3 | iskateley
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | nsoko
# Processing Record 18 of Set 3 | emirdag
# Processing Record 19 of Set 3 | champasak
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 3 | san cristobal
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | wloszczowa
# Processing Record 26 of Set 3 | kwinana
# Processing Record 27 of Set 3 | jiuquan
# Processing Record 28 of Set 3 | pijijiapan
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 3 | puerto escondido
# Processing Record 32 of Set 3 | te anau
# Processing Record 33 of Set 3 | zhuhai
# Processing Record 34 of Set 3 | buraydah
# Processing Record 35 of Set 3 | la merced
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | kloulklubed
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | dingle
# Processing Record 41 of Set 3 | emerald
# Processing Record 42 of Set 3 | lamesa
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | fort saint james
# Processing Record 45 of Set 3 | chapais
# Processing Record 46 of Set 3 | bitung
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | san jeronimo
# Processing Record 49 of Set 3 | dakoro
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | namatanai
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | onega
# Processing Record 5 of Set 4 | jerez
# Processing Record 6 of Set 4 | chicama
# Processing Record 7 of Set 4 | tomaszow lubelski
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | tahoua
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | alyangula
# Processing Record 13 of Set 4 | eskil
# Processing Record 14 of Set 4 | rio gallegos
# Processing Record 15 of Set 4 | chabahar
# Processing Record 16 of Set 4 | nichinan
# Processing Record 17 of Set 4 | adre
# Processing Record 18 of Set 4 | saundatti yellamma
# City not found. Skipping...
# Processing Record 19 of Set 4 | abu samrah
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | lashio
# Processing Record 22 of Set 4 | wilmington
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | sile
# Processing Record 25 of Set 4 | egvekinot
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | bowen
# Processing Record 28 of Set 4 | nisia floresta
# Processing Record 29 of Set 4 | roros
# Processing Record 30 of Set 4 | larkana
# Processing Record 31 of Set 4 | jabinyanah
# Processing Record 32 of Set 4 | abeche
# Processing Record 33 of Set 4 | wangqing
# Processing Record 34 of Set 4 | macenta
# Processing Record 35 of Set 4 | ilulissat
# Processing Record 36 of Set 4 | juazeiro
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | oranjestad
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | saint-augustin
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | aktau
# Processing Record 47 of Set 4 | asau
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | ayan
# Processing Record 50 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 5 | bethel
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | boyolangu
# Processing Record 4 of Set 5 | makakilo city
# Processing Record 5 of Set 5 | silvan
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | englewood
# Processing Record 8 of Set 5 | westport
# Processing Record 9 of Set 5 | faanui
# Processing Record 10 of Set 5 | praia
# Processing Record 11 of Set 5 | uglegorsk
# Processing Record 12 of Set 5 | neya
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | bluff
# Processing Record 15 of Set 5 | waingapu
# Processing Record 16 of Set 5 | korla
# Processing Record 17 of Set 5 | aleppo
# Processing Record 18 of Set 5 | walvis bay
# Processing Record 19 of Set 5 | north bend
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | longhua
# Processing Record 22 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 5 | baraki barak
# Processing Record 24 of Set 5 | mamlyutka
# Processing Record 25 of Set 5 | yurginskoye
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | kieta
# Processing Record 28 of Set 5 | manzanillo
# Processing Record 29 of Set 5 | merauke
# Processing Record 30 of Set 5 | kamaishi
# Processing Record 31 of Set 5 | kongoussi
# Processing Record 32 of Set 5 | ponta pora
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 5 | krasnogorsk
# Processing Record 36 of Set 5 | paamiut
# Processing Record 37 of Set 5 | mabaruma
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 40 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 41 of Set 5 | sao miguel do araguaia
# Processing Record 42 of Set 5 | yichun
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | kiama
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | aswan
# Processing Record 47 of Set 5 | aquiraz
# Processing Record 48 of Set 5 | prainha
# Processing Record 49 of Set 5 | khandyga
# Processing Record 50 of Set 5 | faro
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | carmelo
# Processing Record 3 of Set 6 | itarema
# Processing Record 4 of Set 6 | strezhevoy
# Processing Record 5 of Set 6 | najran
# Processing Record 6 of Set 6 | lasa
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | sept-iles
# Processing Record 9 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 6 | jalalpur pirwala
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | angra
# City not found. Skipping...
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | glenwood springs
# Processing Record 15 of Set 6 | borzya
# Processing Record 16 of Set 6 | mount gambier
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | dalhousie
# Processing Record 19 of Set 6 | castro
# Processing Record 20 of Set 6 | yaan
# Processing Record 21 of Set 6 | guangyuan
# Processing Record 22 of Set 6 | shaowu
# Processing Record 23 of Set 6 | vanimo
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 26 of Set 6 | zuwarah
# Processing Record 27 of Set 6 | port shepstone
# Processing Record 28 of Set 6 | galle
# Processing Record 29 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | mixtequilla
# City not found. Skipping...
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | tual
# Processing Record 33 of Set 6 | estacion coahuila
# Processing Record 34 of Set 6 | palmer
# Processing Record 35 of Set 6 | erenhot
# Processing Record 36 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 37 of Set 6 | reconquista
# Processing Record 38 of Set 6 | turka
# Processing Record 39 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 40 of Set 6 | velke opatovice
# Processing Record 41 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 6 | sao felix do xingu
# Processing Record 43 of Set 6 | thunder bay
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | inverell
# Processing Record 46 of Set 6 | garden city
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | antigonish
# Processing Record 49 of Set 6 | don benito
# Processing Record 50 of Set 6 | souillac
# Processing Record 1 of Set 7 | sabha
# Processing Record 2 of Set 7 | porto walter
# Processing Record 3 of Set 7 | jind
# Processing Record 4 of Set 7 | sola
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | dikson
# Processing Record 7 of Set 7 | autazes
# Processing Record 8 of Set 7 | knysna
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | lichuan
# Processing Record 12 of Set 7 | atambua
# Processing Record 13 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | menongue
# Processing Record 15 of Set 7 | waseca
# Processing Record 16 of Set 7 | novikovo
# Processing Record 17 of Set 7 | saldanha
# Processing Record 18 of Set 7 | krumovgrad
# Processing Record 19 of Set 7 | kalangala
# Processing Record 20 of Set 7 | matara
# Processing Record 21 of Set 7 | canaries
# Processing Record 22 of Set 7 | sioux lookout
# Processing Record 23 of Set 7 | methala
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | padang
# Processing Record 26 of Set 7 | baracoa
# Processing Record 27 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 7 | khani
# Processing Record 29 of Set 7 | muzhi
# Processing Record 30 of Set 7 | port alfred
# Processing Record 31 of Set 7 | iracoubo
# Processing Record 32 of Set 7 | severo-yeniseyskiy
# Processing Record 33 of Set 7 | lukovetskiy
# Processing Record 34 of Set 7 | lethem
# Processing Record 35 of Set 7 | bima
# Processing Record 36 of Set 7 | nanning
# Processing Record 37 of Set 7 | cairns
# Processing Record 38 of Set 7 | gandu
# Processing Record 39 of Set 7 | bonneville
# Processing Record 40 of Set 7 | bandar-e lengeh
# Processing Record 41 of Set 7 | innisfail
# Processing Record 42 of Set 7 | nyurba
# Processing Record 43 of Set 7 | chulym
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | whitianga
# Processing Record 46 of Set 7 | namibe
# Processing Record 47 of Set 7 | fallon
# Processing Record 48 of Set 7 | la ronge
# Processing Record 49 of Set 7 | numan
# Processing Record 50 of Set 7 | monterey
# Processing Record 1 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | kokstad
# Processing Record 3 of Set 8 | vaitape
# Processing Record 4 of Set 8 | waw
# Processing Record 5 of Set 8 | caiaponia
# Processing Record 6 of Set 8 | nome
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | caravelas
# Processing Record 9 of Set 8 | eyl
# Processing Record 10 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 8 | jalingo
# Processing Record 12 of Set 8 | mao
# Processing Record 13 of Set 8 | skoghall
# Processing Record 14 of Set 8 | illapel
# Processing Record 15 of Set 8 | norman wells
# Processing Record 16 of Set 8 | redcliffe
# Processing Record 17 of Set 8 | victoria point
# Processing Record 18 of Set 8 | raha
# Processing Record 19 of Set 8 | manggar
# Processing Record 20 of Set 8 | airai
# Processing Record 21 of Set 8 | tymovskoye
# Processing Record 22 of Set 8 | hudson bay
# Processing Record 23 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 8 | tautira
# Processing Record 25 of Set 8 | jalu
# Processing Record 26 of Set 8 | svelgen
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | whitecourt
# Processing Record 29 of Set 8 | cascina
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | mehamn
# Processing Record 32 of Set 8 | pringsewu
# Processing Record 33 of Set 8 | antofagasta
# Processing Record 34 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 8 | erdenet
# Processing Record 36 of Set 8 | melfort
# Processing Record 37 of Set 8 | songjianghe
# Processing Record 38 of Set 8 | presidencia roque saenz pena
# Processing Record 39 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 8 | komsomolskiy
# Processing Record 41 of Set 8 | klyuchi
# Processing Record 42 of Set 8 | kijang
# Processing Record 43 of Set 8 | datia
# Processing Record 44 of Set 8 | lagoa
# Processing Record 45 of Set 8 | uyuni
# Processing Record 46 of Set 8 | matay
# Processing Record 47 of Set 8 | guadalupe
# Processing Record 48 of Set 8 | saeby
# Processing Record 49 of Set 8 | baker city
# Processing Record 50 of Set 8 | castilho
# Processing Record 1 of Set 9 | sitka
# Processing Record 2 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 9 | labe
# Processing Record 4 of Set 9 | gulu
# Processing Record 5 of Set 9 | cayenne
# Processing Record 6 of Set 9 | solano
# Processing Record 7 of Set 9 | simao
# Processing Record 8 of Set 9 | sistranda
# Processing Record 9 of Set 9 | tutrakan
# Processing Record 10 of Set 9 | srednekolymsk
# Processing Record 11 of Set 9 | gazanjyk
# Processing Record 12 of Set 9 | pisco
# Processing Record 13 of Set 9 | pasni
# Processing Record 14 of Set 9 | manzhouli
# Processing Record 15 of Set 9 | hamilton
# Processing Record 16 of Set 9 | kununurra
# Processing Record 17 of Set 9 | wana
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | suntar
# Processing Record 20 of Set 9 | saint-philippe
# Processing Record 21 of Set 9 | rakaia
# Processing Record 22 of Set 9 | santander
# Processing Record 23 of Set 9 | burns lake
# Processing Record 24 of Set 9 | lexington-fayette
# Processing Record 25 of Set 9 | yatou
# Processing Record 26 of Set 9 | roald
# Processing Record 27 of Set 9 | acapulco
# Processing Record 28 of Set 9 | port moresby
# Processing Record 29 of Set 9 | longyearbyen
# Processing Record 30 of Set 9 | lavrentiya
# Processing Record 31 of Set 9 | montepuez
# Processing Record 32 of Set 9 | conceicao do araguaia
# Processing Record 33 of Set 9 | alnashi
# Processing Record 34 of Set 9 | talnakh
# Processing Record 35 of Set 9 | am timan
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | antequera
# Processing Record 38 of Set 9 | rudsar
# Processing Record 39 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 9 | channel-port aux basques
# Processing Record 42 of Set 9 | inhambane
# Processing Record 43 of Set 9 | carlyle
# Processing Record 44 of Set 9 | bitlis
# Processing Record 45 of Set 9 | marsabit
# Processing Record 46 of Set 9 | lakki marwat
# Processing Record 47 of Set 9 | rawson
# Processing Record 48 of Set 9 | sikasso
# Processing Record 49 of Set 9 | pedro ii
# Processing Record 50 of Set 9 | brae
# Processing Record 1 of Set 10 | wiarton
# Processing Record 2 of Set 10 | klaksvik
# Processing Record 3 of Set 10 | peruibe
# Processing Record 4 of Set 10 | flinders
# Processing Record 5 of Set 10 | tullow
# Processing Record 6 of Set 10 | dandong
# Processing Record 7 of Set 10 | goundam
# Processing Record 8 of Set 10 | fort nelson
# Processing Record 9 of Set 10 | cherskiy
# Processing Record 10 of Set 10 | uige
# Processing Record 11 of Set 10 | baykit
# Processing Record 12 of Set 10 | slave lake
# Processing Record 13 of Set 10 | champerico
# Processing Record 14 of Set 10 | silifke
# Processing Record 15 of Set 10 | colomi
# Processing Record 16 of Set 10 | urumqi
# Processing Record 17 of Set 10 | kidal
# Processing Record 18 of Set 10 | saint-georges
# Processing Record 19 of Set 10 | voloshka
# Processing Record 20 of Set 10 | batagay-alyta
# Processing Record 21 of Set 10 | de aar
# Processing Record 22 of Set 10 | matagami
# Processing Record 23 of Set 10 | agua verde
# Processing Record 24 of Set 10 | clarence town
# Processing Record 25 of Set 10 | castelo do piaui
# Processing Record 26 of Set 10 | kushima
# Processing Record 27 of Set 10 | tingi
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | hami
# Processing Record 30 of Set 10 | copiapo
# Processing Record 31 of Set 10 | aykhal
# Processing Record 32 of Set 10 | tamale
# Processing Record 33 of Set 10 | skvyra
# Processing Record 34 of Set 10 | broome
# Processing Record 35 of Set 10 | tommot
# Processing Record 36 of Set 10 | bereda
# Processing Record 37 of Set 10 | aranos
# Processing Record 38 of Set 10 | kryve ozero
# Processing Record 39 of Set 10 | ossora
# Processing Record 40 of Set 10 | hammerfest
# Processing Record 41 of Set 10 | gameleira
# Processing Record 42 of Set 10 | issenye
# Processing Record 43 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 44 of Set 10 | kampot
# Processing Record 45 of Set 10 | plainview
# Processing Record 46 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 47 of Set 10 | riyadh
# Processing Record 48 of Set 10 | sidney
# Processing Record 49 of Set 10 | livadia
# Processing Record 50 of Set 10 | jicin
# Processing Record 1 of Set 11 | sao teotonio
# Processing Record 2 of Set 11 | san quintin
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | chernyshevskiy
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | massakory
# Processing Record 7 of Set 11 | avera
# Processing Record 8 of Set 11 | banswara
# Processing Record 9 of Set 11 | debre zeyit
# Processing Record 10 of Set 11 | anito
# Processing Record 11 of Set 11 | sabzevar
# Processing Record 12 of Set 11 | ambanja
# Processing Record 13 of Set 11 | kupang
# Processing Record 14 of Set 11 | shimoda
# Processing Record 15 of Set 11 | andros town
# Processing Record 16 of Set 11 | tailai
# Processing Record 17 of Set 11 | santa magdalena
# Processing Record 18 of Set 11 | colares
# Processing Record 19 of Set 11 | awbari
# Processing Record 20 of Set 11 | gerash
# Processing Record 21 of Set 11 | sambava
# Processing Record 22 of Set 11 | grindavik
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | mahibadhoo
# Processing Record 25 of Set 11 | donskoye
# Processing Record 26 of Set 11 | bandar
# Processing Record 27 of Set 11 | san policarpo
# Processing Record 28 of Set 11 | mnogovershinnyy
# Processing Record 29 of Set 11 | terrace
# Processing Record 30 of Set 11 | agua dulce
# Processing Record 31 of Set 11 | petrozavodsk
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | deer lake
# Processing Record 34 of Set 11 | rabo de peixe
# Processing Record 35 of Set 11 | soavinandriana
# Processing Record 36 of Set 11 | bagdarin
# Processing Record 37 of Set 11 | lormi
# Processing Record 38 of Set 11 | villa altagracia
# Processing Record 39 of Set 11 | goma
# Processing Record 40 of Set 11 | aksu
# Processing Record 41 of Set 11 | mehran
# Processing Record 42 of Set 11 | luanda
# Processing Record 43 of Set 11 | catuday
# Processing Record 44 of Set 11 | belmonte
# Processing Record 45 of Set 11 | sobolevo
# Processing Record 46 of Set 11 | liliani
# Processing Record 47 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 11 | barwaha
# City not found. Skipping...
# Processing Record 49 of Set 11 | lompoc
# Processing Record 50 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 12 | the valley
# Processing Record 2 of Set 12 | gorin
# Processing Record 3 of Set 12 | salinopolis
# Processing Record 4 of Set 12 | seoul
# Processing Record 5 of Set 12 | telc
# Processing Record 6 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 7 of Set 12 | ghanzi
# Processing Record 8 of Set 12 | vestmanna
# Processing Record 9 of Set 12 | ovalle
# Processing Record 10 of Set 12 | nabire
# Processing Record 11 of Set 12 | hilton head island
# Processing Record 12 of Set 12 | krasnyy chikoy
# Processing Record 13 of Set 12 | sorland
# Processing Record 14 of Set 12 | shache
# Processing Record 15 of Set 12 | kudahuvadhoo
# Processing Record 16 of Set 12 | honggang
# Processing Record 17 of Set 12 | trinidad
# Processing Record 18 of Set 12 | akyab
# Processing Record 19 of Set 12 | gravelbourg
# Processing Record 20 of Set 12 | susehri
# Processing Record 21 of Set 12 | xining
# Processing Record 22 of Set 12 | linjiang
# Processing Record 23 of Set 12 | puerto maldonado
# Processing Record 24 of Set 12 | ovre ardal
# Processing Record 25 of Set 12 | progreso
# Processing Record 26 of Set 12 | invermere
# Processing Record 27 of Set 12 | araouane
# Processing Record 28 of Set 12 | fecamp
# Processing Record 29 of Set 12 | kabo
# Processing Record 30 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 12 | aksarayskiy
# Processing Record 32 of Set 12 | kyshtovka
# Processing Record 33 of Set 12 | labytnangi
# Processing Record 34 of Set 12 | port said
# Processing Record 35 of Set 12 | taltal
# Processing Record 36 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 12 | marfino
# Processing Record 38 of Set 12 | puerto madryn
# Processing Record 39 of Set 12 | qaqortoq
# Processing Record 40 of Set 12 | santa marta
# Processing Record 41 of Set 12 | kenai
# Processing Record 42 of Set 12 | tongliao
# Processing Record 43 of Set 12 | ongwediva
# Processing Record 44 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 45 of Set 12 | kemijarvi
# Processing Record 46 of Set 12 | necochea
# Processing Record 47 of Set 12 | vardo
# Processing Record 48 of Set 12 | hermiston
# Processing Record 49 of Set 12 | borogontsy
# Processing Record 50 of Set 12 | chara
# Processing Record 1 of Set 13 | sovetskiy
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | gallup
# Processing Record 4 of Set 13 | mushie
# Processing Record 5 of Set 13 | itacare
# Processing Record 6 of Set 13 | virginia beach
# Processing Record 7 of Set 13 | trincomalee
# Processing Record 8 of Set 13 | bagarji
# Processing Record 9 of Set 13 | shelburne
# Processing Record 10 of Set 13 | shubarkuduk
# Processing Record 11 of Set 13 | tuatapere
# Processing Record 12 of Set 13 | wageningen
# Processing Record 13 of Set 13 | mwense
# Processing Record 14 of Set 13 | ler
# Processing Record 15 of Set 13 | hualmay
# Processing Record 16 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 13 | ellwangen
# Processing Record 18 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 13 | menzelinsk
# Processing Record 20 of Set 13 | san-pedro
# Processing Record 21 of Set 13 | zhucheng
# Processing Record 22 of Set 13 | karratha
# Processing Record 23 of Set 13 | umm lajj
# Processing Record 24 of Set 13 | kandrian
# Processing Record 25 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 28 of Set 13 | qasigiannguit
# Processing Record 29 of Set 13 | berdigestyakh
# Processing Record 30 of Set 13 | ilek
# Processing Record 31 of Set 13 | san ramon
# Processing Record 32 of Set 13 | mandali
# Processing Record 33 of Set 13 | ureki
# Processing Record 34 of Set 13 | kiruna
# Processing Record 35 of Set 13 | honiara
# Processing Record 36 of Set 13 | delmas
# Processing Record 37 of Set 13 | kjollefjord
# Processing Record 38 of Set 13 | beringovskiy
# Processing Record 39 of Set 13 | purpe
# Processing Record 40 of Set 13 | kendallville
# Processing Record 41 of Set 13 | poronaysk
# Processing Record 42 of Set 13 | abu kamal
# Processing Record 43 of Set 13 | san patricio
# Processing Record 44 of Set 13 | huaihua
# Processing Record 45 of Set 13 | jacaleapa
# Processing Record 46 of Set 13 | bam
# Processing Record 47 of Set 13 | weyburn
# Processing Record 48 of Set 13 | zarubino
# Processing Record 49 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 13 | bairiki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_sub_df = pd.DataFrame(city_data)
city_data_sub_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Chuy -33.6971  -53.4616     49.10        80           7
# 1    Deputatskiy  69.3000  139.9000     61.41        67          94
# 2   Quatre Cocos -20.2078   57.7625     70.09        67          47
# 3     Georgetown   5.4112  100.3354     81.90        91          20
# 4         Hasaki  35.7333  140.8333     90.28        72          86
# 5   Ponta Do Sol  32.6667  -17.1000     73.00        83           9
# 6      Busselton -33.6500  115.3333     54.86        70          92
# 7        Rikitea -23.1203 -134.9692     72.36        76          10
# 8  Mar Del Plata -38.0023  -57.5575     53.10        86           0
# 9    Yellowknife  62.4560 -114.3525     57.72        82         100
#
#    Wind Speed Country                  Description
# 0        3.11      UY                    clear sky
# 1        3.71      RU              overcast clouds
# 2       17.96      MU                   light rain
# 3        3.44      MY                   few clouds
# 4        1.23      JP              overcast clouds
# 5        6.49      PT                    clear sky
# 6       10.71      AU              overcast clouds
# 7       16.15      PF                   light rain
# 8        8.99      AR                   light rain
# 9        6.91      CA  light intensity shower rain

# %%
new_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]
city_data_sub_df = city_data_sub_df[new_order]
city_data_sub_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Chuy      UY -33.6971  -53.4616     49.10        80           7
# 1    Deputatskiy      RU  69.3000  139.9000     61.41        67          94
# 2   Quatre Cocos      MU -20.2078   57.7625     70.09        67          47
# 3     Georgetown      MY   5.4112  100.3354     81.90        91          20
# 4         Hasaki      JP  35.7333  140.8333     90.28        72          86
# 5   Ponta Do Sol      PT  32.6667  -17.1000     73.00        83           9
# 6      Busselton      AU -33.6500  115.3333     54.86        70          92
# 7        Rikitea      PF -23.1203 -134.9692     72.36        76          10
# 8  Mar Del Plata      AR -38.0023  -57.5575     53.10        86           0
# 9    Yellowknife      CA  62.4560 -114.3525     57.72        82         100
#
#    Wind Speed                  Description
# 0        3.11                    clear sky
# 1        3.71              overcast clouds
# 2       17.96                   light rain
# 3        3.44                   few clouds
# 4        1.23              overcast clouds
# 5        6.49                    clear sky
# 6       10.71              overcast clouds
# 7       16.15                   light rain
# 8        8.99                   light rain
# 9        6.91  light intensity shower rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_sub_df.to_csv(output_data_file, index_label="City_ID")
